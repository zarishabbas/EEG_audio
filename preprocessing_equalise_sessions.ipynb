# %% [markdown]
# ### Import

# %%
import mne
import os
import pandas as pd
from scipy.io import loadmat

# %%
text = pd.read_csv('readme.txt', sep = '\t')

# %% [markdown]
# Function to extract data from .mat files, resample data that was sample at 256 Hz at 128 Hz, and return in mne format.

# %%
def get_data2(filepath, n_channels=19, chan_names = ["Fp1", "Fp2", "F7", "Fz", "F3", "F4", "F8", "T3", "C3", "Cz", "C4", "T4", "T5", "P3", "Pz", "P4", "T6", "O1", "O2"]):
    """
    Input:
    filepath: path to the .mat file
    n_channels: number of channels in the data
    chan_names: names of the channels

    Output:
    info: mne.Info object
    raw: mne.io.RawArray object
    """
    dat = loadmat(filepath)
    sfreq = int(text[text['AD or MCI or CONTROL'] == os.path.basename(os.path.dirname(file))]['sampling rate']) # get sampling frequency from readme.txt

    # export data into mne format
    try:
        X = dat['export']
        info = mne.create_info(ch_names=chan_names[0:20], sfreq=sfreq, ch_types= ['eeg']*n_channels)
        info.set_montage('standard_1020')
        raw = mne.io.RawArray(X.T, info, first_samp=0, copy='auto', verbose=None)
        if info['sfreq'] == 256.0:
            raw.resample(128, npad='auto') # resample to 128Hz
    
    except:
        X = dat['segmenty']
        info = mne.create_info(ch_names=chan_names[0:20], sfreq=sfreq, ch_types= ['eeg']*n_channels)
        info.set_montage('standard_1020')
        raw = mne.io.RawArray(X[0:19], info, first_samp=0, copy='auto', verbose=None)

    return info, raw

# %% [markdown]
# Multiple recording sessions for each particpant are combined into one. The data for each participant is split into equalized sessions of 49 seconds each. THe resulting .fif files are saved in the folder 'mne'.
#
# *Note*. AD and control subjects have multiple recording sessions, whereas control subjects with files ending with "fir.mat" have single recording sessions. Thus data extraction from the two differs.

# %%
data = pd.DataFrame()

subfolders = [f.path for f in os.scandir('dataset2/data') if f.is_dir()]

for name in subfolders:
    children = [f.path for f in os.scandir(name) if f.is_file()]
    if os.path.basename(name) != 'fir':
        raw_dict={}
        raw_out_dict={}
        # combine different recording sessions for each subject
        for n, file in enumerate(children):
            raw_dict[f'info{n}'], raw_dict[f'raw{n}'] = get_data2(file)
        if len(children) > 1:
            raw = mne.concatenate_raws([raw_dict[f'raw{n}'].copy() for n in range(len(children))])
        else:
            raw = raw_dict['raw0'].copy()
        #create output directory
        if not os.path.exists(f'dataset2/data/mne'):
            os.makedirs(f'dataset2/data/mne')
        time_list = [i for i in range(1, int(len(raw)/128), 49)]
        for n, i in enumerate(time_list[:-1]):
            raw_out_dict[f'{n+1}'] = raw.copy().crop(i, time_list[n+1])
            raw_out_dict[f'{n+1}'].save(f"dataset2/data/mne/{os.path.basename(name)}_{n+1}_raw.fif")
            temp_df = pd.DataFrame(raw_out_dict[f'{n+1}']._data.T, columns=raw_out_dict[f'{n+1}'].ch_names)
            temp_df['subject'] = f'{os.path.basename(name)}_{n+1}'
            temp_df['time'] = raw_out_dict[f'{n+1}'].times
            data = data.append(temp_df, ignore_index=True)
    else:
        for n, file in enumerate(children):
            info, raw = get_data2(file)
            #create output directory
            if not os.path.exists(f'dataset2/data/mne'):
                os.makedirs(f'dataset2/data/mne')
            time_list = [i for i in range(1, int(len(raw)/128), 49)]
            for n, i in enumerate(time_list[:-1]):
                raw_out_dict[f'{n+1}'] = raw.copy().crop(i, time_list[n+1])
                raw_out_dict[f'{n+1}'].save(f"dataset2/data/mne/{os.path.basename(file[:-4])}_{n+1}_raw.fif", overwrite=True)
                temp_df = pd.DataFrame(raw_out_dict[f'{n+1}']._data.T, columns=raw_out_dict[f'{n+1}'].ch_names)
                temp_df['subject'] = os.path.basename(file[:-4])
                temp_df['time'] = raw_out_dict[f'{n+1}'].times
                data = data.append(temp_df, ignore_index=True)
# Out:
# Creating RawArray with float64 data, n_channels=19, n_times=10465
#     Range : 0 ... 10464 =      0.000 ...    81.750 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=3576
#     Range : 0 ... 3575 =      0.000 ...    27.930 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=10235
#     Range : 0 ... 10234 =      0.000 ...    79.953 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=8534
#     Range : 0 ... 8533 =      0.000 ...    66.664 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD58_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD58_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD58_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD58_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD58_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD58_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD58_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD58_4_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD58_5_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD58_5_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=30367
#     Range : 0 ... 30366 =      0.000 ...   237.234 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=61655
#     Range : 0 ... 61654 =      0.000 ...   481.672 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_4_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_5_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_5_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_6_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_6_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_7_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_7_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_8_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_8_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_9_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_9_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_10_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_10_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_11_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_11_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_12_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_12_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_13_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_13_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_14_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD38_14_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=1789
#     Range : 0 ... 1788 =      0.000 ...    13.969 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=4700
#     Range : 0 ... 4699 =      0.000 ...    36.711 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=4671
#     Range : 0 ... 4670 =      0.000 ...    36.484 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=8592
#     Range : 0 ... 8591 =      0.000 ...    67.117 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=4527
#     Range : 0 ... 4526 =      0.000 ...    35.359 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=4440
#     Range : 0 ... 4439 =      0.000 ...    34.680 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=7929
#     Range : 0 ... 7928 =      0.000 ...    61.938 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD56_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD56_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD56_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD56_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD56_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD56_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD56_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD56_4_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD56_5_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD56_5_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=23438
#     Range : 0 ... 23437 =      0.000 ...    91.551 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=11532
#     Range : 0 ... 11531 =      0.000 ...    45.043 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=22228
#     Range : 0 ... 22227 =      0.000 ...    86.824 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=12859
#     Range : 0 ... 12858 =      0.000 ...    50.227 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=8304
#     Range : 0 ... 8303 =      0.000 ...    32.434 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=3403
#     Range : 0 ... 3402 =      0.000 ...    13.289 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=2422
#     Range : 0 ... 2421 =      0.000 ...     9.457 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=8102
#     Range : 0 ... 8101 =      0.000 ...    31.645 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=6026
#     Range : 0 ... 6025 =      0.000 ...    23.535 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD9_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD9_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD9_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD9_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD9_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD9_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD9_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD9_4_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD9_5_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD9_5_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD9_6_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD9_6_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD9_7_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD9_7_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=3374
#     Range : 0 ... 3373 =      0.000 ...    26.352 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=4181
#     Range : 0 ... 4180 =      0.000 ...    32.656 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=2855
#     Range : 0 ... 2854 =      0.000 ...    22.297 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=3892
#     Range : 0 ... 3891 =      0.000 ...    30.398 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=3115
#     Range : 0 ... 3114 =      0.000 ...    24.328 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=4729
#     Range : 0 ... 4728 =      0.000 ...    36.938 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=4931
#     Range : 0 ... 4930 =      0.000 ...    38.516 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD48_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD48_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD48_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD48_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD48_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD48_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD48_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD48_4_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=5046
#     Range : 0 ... 5045 =      0.000 ...    19.707 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=3691
#     Range : 0 ... 3690 =      0.000 ...    14.414 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=4815
#     Range : 0 ... 4814 =      0.000 ...    18.805 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD34_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD34_1_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=10725
#     Range : 0 ... 10724 =      0.000 ...    41.891 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=15626
#     Range : 0 ... 15625 =      0.000 ...    61.035 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=5940
#     Range : 0 ... 5939 =      0.000 ...    23.199 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=21680
#     Range : 0 ... 21679 =      0.000 ...    84.684 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD26_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD26_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD26_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD26_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD26_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD26_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD26_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD26_4_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=20786
#     Range : 0 ... 20785 =      0.000 ...    81.191 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=3893
#     Range : 0 ... 3892 =      0.000 ...    15.203 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=33412
#     Range : 0 ... 33411 =      0.000 ...   130.512 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=7727
#     Range : 0 ... 7726 =      0.000 ...    30.180 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD4_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD4_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD4_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD4_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD4_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD4_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD4_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD4_4_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD4_5_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD4_5_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=10264
#     Range : 0 ... 10263 =      0.000 ...    40.090 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=17874
#     Range : 0 ... 17873 =      0.000 ...    69.816 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=11272
#     Range : 0 ... 11271 =      0.000 ...    44.027 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=16663
#     Range : 0 ... 16662 =      0.000 ...    65.086 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=5825
#     Range : 0 ... 5824 =      0.000 ...    22.750 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=14357
#     Range : 0 ... 14356 =      0.000 ...    56.078 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=8505
#     Range : 0 ... 8504 =      0.000 ...    33.219 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD14_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD14_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD14_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD14_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD14_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD14_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD14_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD14_4_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD14_5_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD14_5_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD14_6_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD14_6_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=7900
#     Range : 0 ... 7899 =      0.000 ...    61.711 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=4210
#     Range : 0 ... 4209 =      0.000 ...    32.883 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=15741
#     Range : 0 ... 15740 =      0.000 ...   122.969 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=7497
#     Range : 0 ... 7496 =      0.000 ...    58.562 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=7122
#     Range : 0 ... 7121 =      0.000 ...    55.633 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=6660
#     Range : 0 ... 6659 =      0.000 ...    52.023 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=7093
#     Range : 0 ... 7092 =      0.000 ...    55.406 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=10638
#     Range : 0 ... 10637 =      0.000 ...    83.102 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD36_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD36_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD36_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD36_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD36_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD36_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD36_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD36_4_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD36_5_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD36_5_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD36_6_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD36_6_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD36_7_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD36_7_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD36_8_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD36_8_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD36_9_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD36_9_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD36_10_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD36_10_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=27965
#     Range : 0 ... 27964 =      0.000 ...   109.234 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=8592
#     Range : 0 ... 8591 =      0.000 ...    33.559 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=7121
#     Range : 0 ... 7120 =      0.000 ...    27.812 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=11014
#     Range : 0 ... 11013 =      0.000 ...    43.020 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=4613
#     Range : 0 ... 4612 =      0.000 ...    18.016 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD23_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD23_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD23_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD23_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD23_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD23_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD23_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD23_4_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=10120
#     Range : 0 ... 10119 =      0.000 ...    39.527 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=2769
#     Range : 0 ... 2768 =      0.000 ...    10.812 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=5306
#     Range : 0 ... 5305 =      0.000 ...    20.723 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=10552
#     Range : 0 ... 10551 =      0.000 ...    41.215 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=10869
#     Range : 0 ... 10868 =      0.000 ...    42.453 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=6488
#     Range : 0 ... 6487 =      0.000 ...    25.340 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD8_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD8_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD8_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD8_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD8_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD8_3_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=6948
#     Range : 0 ... 6947 =      0.000 ...    27.137 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=38141
#     Range : 0 ... 38140 =      0.000 ...   148.984 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=5536
#     Range : 0 ... 5535 =      0.000 ...    21.621 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=15135
#     Range : 0 ... 15134 =      0.000 ...    59.117 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=11648
#     Range : 0 ... 11647 =      0.000 ...    45.496 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=11821
#     Range : 0 ... 11820 =      0.000 ...    46.172 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=9716
#     Range : 0 ... 9715 =      0.000 ...    37.949 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=5508
#     Range : 0 ... 5507 =      0.000 ...    21.512 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD12_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD12_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD12_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD12_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD12_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD12_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD12_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD12_4_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD12_5_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD12_5_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD12_6_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD12_6_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD12_7_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD12_7_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD12_8_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD12_8_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=3144
#     Range : 0 ... 3143 =      0.000 ...    24.555 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=6603
#     Range : 0 ... 6602 =      0.000 ...    51.578 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=11618
#     Range : 0 ... 11617 =      0.000 ...    90.758 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=6314
#     Range : 0 ... 6313 =      0.000 ...    49.320 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD42_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD42_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD42_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD42_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD42_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD42_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD42_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD42_4_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=5680
#     Range : 0 ... 5679 =      0.000 ...    44.367 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=17557
#     Range : 0 ... 17556 =      0.000 ...   137.156 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=6286
#     Range : 0 ... 6285 =      0.000 ...    49.102 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=6949
#     Range : 0 ... 6948 =      0.000 ...    54.281 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD52_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD52_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD52_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD52_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD52_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD52_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD52_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD52_4_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD52_5_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD52_5_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=24678
#     Range : 0 ... 24677 =      0.000 ...   192.789 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=4959
#     Range : 0 ... 4958 =      0.000 ...    38.734 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=22343
#     Range : 0 ... 22342 =      0.000 ...   174.547 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD49_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD49_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD49_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD49_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD49_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD49_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD49_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD49_4_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD49_5_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD49_5_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD49_6_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD49_6_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD49_7_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD49_7_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD49_8_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD49_8_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=25399
#     Range : 0 ... 25398 =      0.000 ...    99.211 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=38054
#     Range : 0 ... 38053 =      0.000 ...   148.645 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=15943
#     Range : 0 ... 15942 =      0.000 ...    62.273 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=21852
#     Range : 0 ... 21851 =      0.000 ...    85.355 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD11_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD11_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD11_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD11_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD11_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD11_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD11_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD11_4_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD11_5_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD11_5_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD11_6_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD11_6_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD11_7_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD11_7_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD11_8_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD11_8_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=4585
#     Range : 0 ... 4584 =      0.000 ...    17.906 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=6574
#     Range : 0 ... 6573 =      0.000 ...    25.676 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=21882
#     Range : 0 ... 21881 =      0.000 ...    85.473 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=6978
#     Range : 0 ... 6977 =      0.000 ...    27.254 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=15193
#     Range : 0 ... 15192 =      0.000 ...    59.344 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=6544
#     Range : 0 ... 6543 =      0.000 ...    25.559 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=7467
#     Range : 0 ... 7466 =      0.000 ...    29.164 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD15_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD15_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD15_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD15_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD15_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD15_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD15_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD15_4_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD15_5_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD15_5_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=8303
#     Range : 0 ... 8302 =      0.000 ...    64.859 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=8678
#     Range : 0 ... 8677 =      0.000 ...    67.789 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=9456
#     Range : 0 ... 9455 =      0.000 ...    73.867 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=10552
#     Range : 0 ... 10551 =      0.000 ...    82.430 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=3691
#     Range : 0 ... 3690 =      0.000 ...    28.828 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD50_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD50_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD50_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD50_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD50_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD50_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD50_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD50_4_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD50_5_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD50_5_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD50_6_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD50_6_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=7698
#     Range : 0 ... 7697 =      0.000 ...    30.066 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=4873
#     Range : 0 ... 4872 =      0.000 ...    19.031 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=5622
#     Range : 0 ... 5621 =      0.000 ...    21.957 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=3317
#     Range : 0 ... 3316 =      0.000 ...    12.953 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=4181
#     Range : 0 ... 4180 =      0.000 ...    16.328 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=3086
#     Range : 0 ... 3085 =      0.000 ...    12.051 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=3057
#     Range : 0 ... 3056 =      0.000 ...    11.938 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=6833
#     Range : 0 ... 6832 =      0.000 ...    26.688 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD31_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD31_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD31_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD31_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD31_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD31_3_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=14559
#     Range : 0 ... 14558 =      0.000 ...   113.734 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=8131
#     Range : 0 ... 8130 =      0.000 ...    63.516 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=6746
#     Range : 0 ... 6745 =      0.000 ...    52.695 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=7525
#     Range : 0 ... 7524 =      0.000 ...    58.781 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=2566
#     Range : 0 ... 2565 =      0.000 ...    20.039 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=8621
#     Range : 0 ... 8620 =      0.000 ...    67.344 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=11013
#     Range : 0 ... 11012 =      0.000 ...    86.031 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD43_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD43_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD43_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD43_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD43_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD43_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD43_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD43_4_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD43_5_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD43_5_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD43_6_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD43_6_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD43_7_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD43_7_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD43_8_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD43_8_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD43_9_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD43_9_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=2250
#     Range : 0 ... 2249 =      0.000 ...    17.570 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=2625
#     Range : 0 ... 2624 =      0.000 ...    20.500 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=2596
#     Range : 0 ... 2595 =      0.000 ...    20.273 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=6574
#     Range : 0 ... 6573 =      0.000 ...    51.352 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=2884
#     Range : 0 ... 2883 =      0.000 ...    22.523 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=4700
#     Range : 0 ... 4699 =      0.000 ...    36.711 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD57_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD57_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD57_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD57_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD57_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD57_3_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=6430
#     Range : 0 ... 6429 =      0.000 ...    25.113 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=24908
#     Range : 0 ... 24907 =      0.000 ...    97.293 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=36353
#     Range : 0 ... 36352 =      0.000 ...   142.000 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=9716
#     Range : 0 ... 9715 =      0.000 ...    37.949 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=6141
#     Range : 0 ... 6140 =      0.000 ...    23.984 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=3691
#     Range : 0 ... 3690 =      0.000 ...    14.414 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD20_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD20_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD20_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD20_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD20_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD20_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD20_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD20_4_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD20_5_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD20_5_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD20_6_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD20_6_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=1183
#     Range : 0 ... 1182 =      0.000 ...     9.234 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=1327
#     Range : 0 ... 1326 =      0.000 ...    10.359 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=2106
#     Range : 0 ... 2105 =      0.000 ...    16.445 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=2019
#     Range : 0 ... 2018 =      0.000 ...    15.766 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD55_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD55_1_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=6660
#     Range : 0 ... 6659 =      0.000 ...    26.012 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=5507
#     Range : 0 ... 5506 =      0.000 ...    21.508 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=3893
#     Range : 0 ... 3892 =      0.000 ...    15.203 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=3403
#     Range : 0 ... 3402 =      0.000 ...    13.289 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=3633
#     Range : 0 ... 3632 =      0.000 ...    14.188 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=4441
#     Range : 0 ... 4440 =      0.000 ...    17.344 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=2710
#     Range : 0 ... 2709 =      0.000 ...    10.582 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=2710
#     Range : 0 ... 2709 =      0.000 ...    10.582 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=24418
#     Range : 0 ... 24417 =      0.000 ...    95.379 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD10_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD10_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD10_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD10_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD10_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD10_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD10_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD10_4_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=7497
#     Range : 0 ... 7496 =      0.000 ...    58.562 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=8275
#     Range : 0 ... 8274 =      0.000 ...    64.641 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=10293
#     Range : 0 ... 10292 =      0.000 ...    80.406 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=12224
#     Range : 0 ... 12223 =      0.000 ...    95.492 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=5478
#     Range : 0 ... 5477 =      0.000 ...    42.789 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=3720
#     Range : 0 ... 3719 =      0.000 ...    29.055 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD37_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD37_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD37_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD37_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD37_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD37_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD37_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD37_4_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD37_5_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD37_5_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD37_6_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD37_6_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD37_7_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD37_7_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=4700
#     Range : 0 ... 4699 =      0.000 ...    36.711 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=11475
#     Range : 0 ... 11474 =      0.000 ...    89.641 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=3633
#     Range : 0 ... 3632 =      0.000 ...    28.375 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=3547
#     Range : 0 ... 3546 =      0.000 ...    27.703 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD51_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD51_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD51_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD51_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD51_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD51_3_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=38256
#     Range : 0 ... 38255 =      0.000 ...   149.434 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=38083
#     Range : 0 ... 38082 =      0.000 ...   148.758 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=37967
#     Range : 0 ... 37966 =      0.000 ...   148.305 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD22_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD22_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD22_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD22_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD22_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD22_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD22_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD22_4_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD22_5_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD22_5_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD22_6_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD22_6_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD22_7_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD22_7_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD22_8_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD22_8_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD22_9_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD22_9_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=2307
#     Range : 0 ... 2306 =      0.000 ...    18.016 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=2567
#     Range : 0 ... 2566 =      0.000 ...    20.047 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=1846
#     Range : 0 ... 1845 =      0.000 ...    14.414 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/normal2_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/normal2_1_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=11008
#     Range : 0 ... 11007 =      0.000 ...    85.992 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/15622fir_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/15622fir_1_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=9216
#     Range : 0 ... 9215 =      0.000 ...    71.992 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/2333fir_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/2333fir_1_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=10752
#     Range : 0 ... 10751 =      0.000 ...    83.992 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/24283fir_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/24283fir_1_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=11264
#     Range : 0 ... 11263 =      0.000 ...    87.992 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/12667fir_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/12667fir_1_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=7168
#     Range : 0 ... 7167 =      0.000 ...    55.992 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/3924fir_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/3924fir_1_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=7936
#     Range : 0 ... 7935 =      0.000 ...    61.992 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/26263fir_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/26263fir_1_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=13056
#     Range : 0 ... 13055 =      0.000 ...   101.992 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/23330fir_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/23330fir_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/23330fir_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/23330fir_2_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=8448
#     Range : 0 ... 8447 =      0.000 ...    65.992 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/5045fir_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/5045fir_1_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=8704
#     Range : 0 ... 8703 =      0.000 ...    67.992 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/15815fir_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/15815fir_1_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=9472
#     Range : 0 ... 9471 =      0.000 ...    73.992 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/17264fir_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/17264fir_1_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=8960
# ...
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD6_6_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=4960
#     Range : 0 ... 4959 =      0.000 ...    38.742 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=2941
#     Range : 0 ... 2940 =      0.000 ...    22.969 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=6862
#     Range : 0 ... 6861 =      0.000 ...    53.602 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD59_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD59_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD59_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD59_2_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=3547
#     Range : 0 ... 3546 =      0.000 ...    13.852 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=4700
#     Range : 0 ... 4699 =      0.000 ...    18.355 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=4844
#     Range : 0 ... 4843 =      0.000 ...    18.918 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=7957
#     Range : 0 ... 7956 =      0.000 ...    31.078 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=15049
#     Range : 0 ... 15048 =      0.000 ...    58.781 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD25_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD25_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD25_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD25_2_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=5392
#     Range : 0 ... 5391 =      0.000 ...    21.059 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=5248
#     Range : 0 ... 5247 =      0.000 ...    20.496 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=6574
#     Range : 0 ... 6573 =      0.000 ...    25.676 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=6084
#     Range : 0 ... 6083 =      0.000 ...    23.762 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=9918
#     Range : 0 ... 9917 =      0.000 ...    38.738 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=9255
#     Range : 0 ... 9254 =      0.000 ...    36.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=3000
#     Range : 0 ... 2999 =      0.000 ...    11.715 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD30_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD30_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD30_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD30_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD30_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD30_3_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=7612
#     Range : 0 ... 7611 =      0.000 ...    59.461 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=6054
#     Range : 0 ... 6053 =      0.000 ...    47.289 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=16578
#     Range : 0 ... 16577 =      0.000 ...   129.508 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=3979
#     Range : 0 ... 3978 =      0.000 ...    31.078 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=19662
#     Range : 0 ... 19661 =      0.000 ...   153.602 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD41_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD41_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD41_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD41_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD41_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD41_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD41_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD41_4_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD41_5_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD41_5_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD41_6_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD41_6_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD41_7_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD41_7_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD41_8_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD41_8_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=10292
#     Range : 0 ... 10291 =      0.000 ...    80.398 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=3230
#     Range : 0 ... 3229 =      0.000 ...    25.227 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=16404
#     Range : 0 ... 16403 =      0.000 ...   128.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=6228
#     Range : 0 ... 6227 =      0.000 ...    48.648 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=7064
#     Range : 0 ... 7063 =      0.000 ...    55.180 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=8707
#     Range : 0 ... 8706 =      0.000 ...    68.016 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=6314
#     Range : 0 ... 6313 =      0.000 ...    49.320 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/normal1_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/normal1_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/normal1_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/normal1_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/normal1_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/normal1_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/normal1_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/normal1_4_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/normal1_5_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/normal1_5_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/normal1_6_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/normal1_6_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/normal1_7_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/normal1_7_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/normal1_8_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/normal1_8_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/normal1_9_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/normal1_9_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=11561
#     Range : 0 ... 11560 =      0.000 ...    90.312 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=11821
#     Range : 0 ... 11820 =      0.000 ...    92.344 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD39_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD39_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD39_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD39_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD39_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD39_3_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=6401
#     Range : 0 ... 6400 =      0.000 ...    25.000 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=16087
#     Range : 0 ... 16086 =      0.000 ...    62.836 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=15049
#     Range : 0 ... 15048 =      0.000 ...    58.781 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=20700
#     Range : 0 ... 20699 =      0.000 ...    80.855 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=21708
#     Range : 0 ... 21707 =      0.000 ...    84.793 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=6228
#     Range : 0 ... 6227 =      0.000 ...    24.324 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=4383
#     Range : 0 ... 4382 =      0.000 ...    17.117 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=9399
#     Range : 0 ... 9398 =      0.000 ...    36.711 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD27_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD27_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD27_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD27_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD27_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD27_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD27_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD27_4_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD27_5_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD27_5_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD27_6_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD27_6_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD27_7_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD27_7_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=37910
#     Range : 0 ... 37909 =      0.000 ...   148.082 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=23179
#     Range : 0 ... 23178 =      0.000 ...    90.539 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=12022
#     Range : 0 ... 12021 =      0.000 ...    46.957 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=7727
#     Range : 0 ... 7726 =      0.000 ...    30.180 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=12137
#     Range : 0 ... 12136 =      0.000 ...    47.406 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=6372
#     Range : 0 ... 6371 =      0.000 ...    24.887 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=8448
#     Range : 0 ... 8447 =      0.000 ...    32.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=5017
#     Range : 0 ... 5016 =      0.000 ...    19.594 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=3691
#     Range : 0 ... 3690 =      0.000 ...    14.414 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=13290
#     Range : 0 ... 13289 =      0.000 ...    51.910 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD18_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD18_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD18_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD18_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD18_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD18_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD18_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD18_4_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD18_5_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD18_5_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD18_6_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD18_6_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD18_7_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD18_7_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD18_8_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD18_8_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD18_9_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD18_9_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD18_10_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD18_10_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=7093
#     Range : 0 ... 7092 =      0.000 ...    27.703 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=38025
#     Range : 0 ... 38024 =      0.000 ...   148.531 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=6833
#     Range : 0 ... 6832 =      0.000 ...    26.688 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=15568
#     Range : 0 ... 15567 =      0.000 ...    60.809 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=12455
#     Range : 0 ... 12454 =      0.000 ...    48.648 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=11071
#     Range : 0 ... 11070 =      0.000 ...    43.242 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=11216
#     Range : 0 ... 11215 =      0.000 ...    43.809 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD24_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD24_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD24_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD24_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD24_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD24_3_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD24_4_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD24_4_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD24_5_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD24_5_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD24_6_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD24_6_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD24_7_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD24_7_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD24_8_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD24_8_raw.fif
# [done]
# Creating RawArray with float64 data, n_channels=19, n_times=6891
#     Range : 0 ... 6890 =      0.000 ...    53.828 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=15597
#     Range : 0 ... 15596 =      0.000 ...   121.844 secs
# Ready.
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD54_1_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD54_1_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD54_2_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD54_2_raw.fif
# [done]
# Writing /home/zarishabbas/Documents/final/dataset2/data/mne/AD54_3_raw.fif
# Closing /home/zarishabbas/Documents/final/dataset2/data/mne/AD54_3_raw.fif
# [done]

# %% [markdown]
# Save the data in csv format.

# %%
data.to_csv('dataset2/data/raw_mne_data.csv', index=False)
